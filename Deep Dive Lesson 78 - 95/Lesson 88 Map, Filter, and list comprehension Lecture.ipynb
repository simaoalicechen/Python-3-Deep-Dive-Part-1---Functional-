# %%
'''
High order functions 

A function that takes a function as a parameter and /or returns a function as its return value 
Example: sorted 
map
filter ---> modern alternative --> list comprehensions and generator expressions 
The map function 
map(func, *iterables)
*iterables -> a variable number of iterabl objects 
func -> some function that takes as many arguments as there are iterable objects passed to iterables 

map(func, *iterable) will then return an iterator that calculates the function applied to each element of the iterables 

The iterator stops as soon as as one of the iterables has been exahausted so, unqueal length iterabls can be used. 

l = [2,3,4]
def sq(x): 
    return x**2

list(map(sq,l)) ---> [4,9,16]

Stops whenever an input exhausts


The filter function 

filter(func, iterable)

iterable ----> a single iterable 
func -----> some functiong that takes a single argument 
filter(func, iterable) will then return an iterator that contains all teh elements of the iterabl 
for which the function called on it is TRUTHY


If the function is NOne, it simply returns the elements of iterable that are Truthy 


Example 
l = [0,1,2,3,4]
list(filter(None,l)) --> [1,2,3,4]
def is_even(n): 
    return n%2 ==0

list(filter(is_even, l))



The zip function (NOT a higher order function)

zip(*iterables)
[1,2,3,4]
[10,20,30,40] -----> zip (1,10), (2,20), (3,30), (4,40)

['a','b','c'] ----->  (1,10,'a'), (2,20, 'b') ......

['python']  = (1,10,'a', 'p'), (2,20, 'b', 'y').........

Once one iterable is exhausted, it stops. 

l1 = range(1000)
ls = 'abcedefghijk'


This ZIP can help us find out the index of the character in a string. 


List Comprehension (with zip) Alternative to Map 

[<expression> for <varname> in <iterable>]


list(map(lambda x,y: x+y, l1, l2)) ----> [11,22,33] 
Remember: zip(l1, l2) -->[(1,10), (2,20), (3,30)] 

[x+y for x,y in zip(l1,l2)] 


List Comprehension (with zip) Alternative to filter

l=[1,2,3,4]
list(filter(lambda n: n%2 ==0,l)) -->[2,4] 
[x for x in l if x%2 == 0] ---->[2,4]

[<expressin1> for <varname> in <iterable> if <expression2>]

Combining map and filter 

l = range(10)

list(filter(lambda y:y<25, map(lambda x:x**2, l))) ----> [0,1,4,9,16]

Using a list comprehension is much clearer: 

[x**2 for xin range(10) if x**2 <25] --> [0,1,4,9,16] 




'''
