# %%
'''
Recal


Positional arguments                                                   keyword-only arguments 

specific may have defualt values                                     after positional arguments have been exhausted
*args, collects and exhausts remaining positional arguments          specific           may have default values 
* indicates the end of positional arguments (effective exhausts)     **kwargs

a,b,c = 10        positional parameters/ can have defualt values/ non-defaulted params are mandatory args/ 
            users may specify thm using keywords.
*args/*           scoops up any additional positional args/* indicates no more positional args, only named args are allowed afterwards. 
kw1, kw2 = 100    specific keyword-only args, / specifically named keyword only arguments, great for use after *./ 
                    can have default values / non-defaulted params are mandatory args //
                    user must specifiy them using keywords if used, * or ** must also be used 
                    
**kwargs          scoops up any additional keyword args/

Examples 

def func(a, b = 10)
def func(a,b, *args)
def func(a,b,*args, kw1, kw2 = 100)
def func(a,b,*, kw1, kw2 = 100)
def func(a,b,*args, kw1, kw2 = 100, **kwargs)
def func(a,b,*, kw1, kw2 = 100, **kwargs)
def func(*args)
def func(*kwargs)
def func(*args, *kwargs)



Typical Use Case: 
Python's print() function 
PRINT FUNCTION

*objects, sep = '', end = '\n', file = sys.stdout, flush = False 

Objects:    arbitrary number of positional arguments 

after that they are only keyword-only arguments 

Typical Use cases 
often, keyword-only arguements are used to modify the defualt behavior of a function 
such as the print() function we just saw 
def func(*args, log_to_console = False): 
    ......
    return 
    
Other times, keyword-only arguments might be sued to make things clear. 

Having many positional parameters can become confusing, 
and extra care has to be taken to ensure the correct paramters are passed in the correct sequence. 






'''
