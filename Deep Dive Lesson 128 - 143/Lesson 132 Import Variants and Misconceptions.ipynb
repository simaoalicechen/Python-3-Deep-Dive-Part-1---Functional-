# %%
'''
import variants
# module1.py
import math 
is math in sys.modules? if not, load it and insert ref 

sys.modules
math   <module object>

add symbol math to modeul's global namespace refereencing the same object. 

module2.globals(): math <module object> math symbol in namespace 
(if math symbol already exists in module's namespace, replace reference)


# module1.py

import math as r_math

is math in sys.modules? if not, load it and insert ref

sys.modules math <module object>

add symbol r_math to modeul's global namespace refereencing the same object. 

module1.globals(): r_math <module object> r_math symbol in namespace 
(if r_math symbol already exists in module1's namespace, replace reference)


import variants 

# module1.py

from math import sqrt 

is math in sys.modules? 
if not, load it and insert ref sys.modules math <module object> 

add symbol sqrt to module1's global namespace referencing math.sqrt
module1.globals() sqrt <math.sqrt object> math symbol NOT in namespace 

if sqrt ysmbol already exists in module1's namespace, replace reference

>>>



Commonality 

In every case the manth module was loaded into memory and referenced in sys.modules 

Running from math import sqrt 

did not "partically load math" 

it only affected what symbols were placed in module1's namespace! 

Things may be different with packages, but for simple modules this is the behavior 



Why from <module> import * can lead to bugs 

# module1.py 
fro cmath import * module1.globals() sqrt <cmath.sqrt> 

import * sometimes overimposes the previous one. Be careful. 

Eficiency 

What is more efficient? 

Import math or 
from math import sqrt 

importing --> same amount of work 

coalling math.sqrt(2) --> This first needs to find the sqrt symbol in math's namespace 
sqrt(2) --> This is from the function being called, dictionary lookup ---> super fast! (but doesn't make
that much difference if only being called a few times.)


'''
