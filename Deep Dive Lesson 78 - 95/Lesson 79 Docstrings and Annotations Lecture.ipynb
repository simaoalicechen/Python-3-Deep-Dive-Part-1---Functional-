# %%
'''
Docstrings  
We have seen teh help(x) function before ------> returns some documentation (if available) for x
We can document our functions (and module, classes, etc) to achieve the smae result using docstrings ---> PEP257

If the first line in the function body is a string (not an assignment, not a comment, just a stirng by itself), 
it will be interpreted as a docstring. 

def my_func(a):                               help(my_func)
    "documentation for my_func"                   -----> my_func(a)
    return a                                          documentation for my_func


Multi-line docstrings are achieved using multi-line strings! 

Triple ''''''


Where are docstrings stored? 
In the fuction's __doc___ property 

def fact(n): 
    
    calculates n! (factorial function)
    inputs: 
        n 
    Returns: 
        the factorial of n 
    .....
    fact.__doc__ ----->     calculates n! (factorial function)\n inputs:\n n\n Returns:\n the factorial of n 

help(fact): fact(n) 

Function Annotations 

Function annotations give us an additional way to document functions: ----> PEP 3107
def my_func(a: <expression>, b: <expression>) -> <expression>:
    pass
    
def my_func(a: 'a string', b: 'a positive integer') -> 'a string': 
    return a*b

my_func.__doc__---> empty string 
Annotations can be any expression 

b:[1,2,3]
Annotations do not change how your codes run at all. Even if they say a is a string, a does not need to be a string 

Default values< *args, **kwars 
can still be used as before 

--> dictionary keys are the parameter names for a return annotation, the key is return 
values are the annotations 


Where does Python use docstrings and annotations? 

It doesn't. Mainly used by external tools and modules 

Example: applications that generate documentation from your code (Sphinx)

Docstrings and annotations are entirely optional and do not force anything in our Python code 

We will look at a enhanced version of annoation: type hints 
    
'''
